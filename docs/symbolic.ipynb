# %% [markdown]
# # LaTeX for symbols

# %%
using Symbolics
using Latexify

@variables x y

x^2 + y^2
# Out:
# x^2 + y^2

# %%
latexify(x^2 + y^2)
# Out:
# L"\begin{equation}
# x^{2} + y^{2}
# \end{equation}
# "

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
